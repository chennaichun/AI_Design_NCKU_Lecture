# %% [markdown]
# # python-google-places
# python-google-places provides a simple wrapper around the experimental Google Places API.
#
# Installation
# pip install https://github.com/slimkrazy/python-google-places/zipball/master
#
# OR
#
# pip install python-google-places
#
# Download source and then: python setup.py install

# %% [markdown]
# 應用程式介面（英語：Application Programming Interface，簡稱：API），
# 又稱為應用編程介面，就是軟體系統不同組成部分銜接的約定。

# %% [markdown]
# https://developers.google.com/places/web-service/get-api-key

# %%
YOUR_API_KEY ='AIzaSyAaeGQvKfu3U-23Qihg-TSQFUpdbiXvEO0'

# %%
import googlemaps
import pandas as pd
import time
gmaps = googlemaps.Client(key=YOUR_API_KEY)

# %% [markdown]
# https://developers.google.com/places/web-service/search

# %%
cities= ["臺南市"]

# %%
geocode_result = gmaps.geocode("臺南市")
geocode_result
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-27-65b5d4574ceb> in <module>()
# ----> 1 geocode_result = gmaps.geocode("臺南市")
#       2 geocode_result
#
# /anaconda2/lib/python2.7/site-packages/googlemaps/client.pyc in wrapper(*args, **kwargs)
#     363     def wrapper(*args, **kwargs):
#     364         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 365         result = func(*args, **kwargs)
#     366         try:
#     367             del args[0]._extra_params
#
# /anaconda2/lib/python2.7/site-packages/googlemaps/geocoding.pyc in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params).get("results", [])
#      69
#      70
#
# /anaconda2/lib/python2.7/site-packages/googlemaps/client.pyc in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258                 result = extract_body(response)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#     262             return result
#
# /anaconda2/lib/python2.7/site-packages/googlemaps/client.pyc in _get_body(self, response)
#     288
#     289         raise googlemaps.exceptions.ApiError(api_status,
# --> 290                                              body.get("error_message"))
#     291
#     292     def _generate_auth_url(self, path, params, accepts_clientid):
#
# ApiError: REQUEST_DENIED (This API project is not authorized to use this API.)

# %%
data={
            "rating": 5, 
            "name": "STR Analytics", 
            "reference": "CmRRAAAAEyrq32Ve7RKLtI6CWpaAoTFrR2yVWlKTfnbNTmCRLj3yXcIs2k6H45JPPwPZyIpMPxEBfVIqdD9BTWekJliAvgX_OH-FJyYUWnso9oZ2CjN97I2GWhXTSK1TBUo3HBVxEhDRxa-R4nxh8UqHeJPi9LHtGhQ6VMxxTnuXCwm9vZgY0IcnTaqQhg", 
            "geometry": {
                "location": {
                    "lat": 39.9148173, 
                    "lng": -105.1206877
                }, 
                "viewport": {
                    "northeast": {
                        "lat": 39.9158015802915, 
                        "lng": -105.1193284197085
                    }, 
                    "southwest": {
                        "lat": 39.9131036197085, 
                        "lng": -105.1220263802915
                    }
                }
            }, 
            "place_id": "ChIJ1VlFO-Tta4cRGQHpjODHvXU", 
            "formatted_address": "11001 W 120th Ave, Broomfield, CO 80021, United States", 
            "id": "b0003b168c40b2d378933f440b7f9a4116187dc5", 
            "types": [
                "point_of_interest", 
                "establishment"
            ], 
            "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png"
        },
